# %% [markdown]
# ## Scraping information about famous actresses from Wikipedia
#
# Inspired by the Oscars this month, I will practice scraping a webpage by gathering information about actresses.
#
# ##### What process will I follow to accomplish this?
#
# Step 1: Import packages
#
# Step 2: Get the data
#
# Follow the guide from Digital Ocean: https://www.digitalocean.com/community/tutorials/how-to-scrape-web-pages-with-beautiful-soup-and-python-3
#
# And the documentation provided by beautifulsoup: https://www.crummy.com/software/BeautifulSoup/bs4/doc/
#
# Focus on this list 21st Century American Actresses https://en.wikipedia.org/wiki/Category:21st-century_American_actresses

# %% [markdown]
# ##### Step A: Collect our page, parse it, and set it up as a BeautifulSoup object

# %%
#Import libraries
import requests
import bs4
from bs4 import BeautifulSoup
import csv

# Collect 21st Century American Actresses
page = requests.get('https://en.wikipedia.org/wiki/Category:21st-century_American_actresses')

# Collect a beautifulsoup object
soup = BeautifulSoup(page.text, 'html.parser')

# %% [markdown]
# ##### Step B: Collect the data we would like
#
# For this step we will be collecting:
# - Actresses' names
# - Links to their profile

# %%
# Create a file to write to, add headers row
f = csv.writer(open('actress-names.csv', 'w'))
f.writerow(['Name', 'Link'])

# Pull all text from the mw-category div
actress_name_list = soup.find(class_='mw-category')

# Pull text from all instances of <a> tag within mw-category div
actress_name_list_items = actress_name_list.find_all('a')

# Create for loop to print out all actress' names and links
# Use .contents to pull out the <a> tag’s children
for actress_name in actress_name_list_items:
    names = actress_name.contents[0]
    links = 'https://www.wikipedia.org' + actress_name.get('href')
    f.writerow([names, links])
    print(names)
    print(links)
# Out:
# Mariann Aalda
# https://www.wikipedia.org/wiki/Mariann_Aalda
# Aaliyah
# https://www.wikipedia.org/wiki/Aaliyah
# Caroline Aaron
# https://www.wikipedia.org/wiki/Caroline_Aaron
# Rose Abdoo
# https://www.wikipedia.org/wiki/Rose_Abdoo
# Paula Abdul
# https://www.wikipedia.org/wiki/Paula_Abdul
# Donzaleigh Abernathy
# https://www.wikipedia.org/wiki/Donzaleigh_Abernathy
# Whitney Able
# https://www.wikipedia.org/wiki/Whitney_Able
# Amy Acker
# https://www.wikipedia.org/wiki/Amy_Acker
# Allegra Acosta
# https://www.wikipedia.org/wiki/Allegra_Acosta
# Anabelle Acosta
# https://www.wikipedia.org/wiki/Anabelle_Acosta
# Ava Acres
# https://www.wikipedia.org/wiki/Ava_Acres
# Isabella Acres
# https://www.wikipedia.org/wiki/Isabella_Acres
# Tatum Adair
# https://www.wikipedia.org/wiki/Tatum_Adair
# Amy Adams
# https://www.wikipedia.org/wiki/Amy_Adams
# Brooke Adams (actress)
# https://www.wikipedia.org/wiki/Brooke_Adams_(actress)
# Catlin Adams
# https://www.wikipedia.org/wiki/Catlin_Adams
# Jane Adams (actress)
# https://www.wikipedia.org/wiki/Jane_Adams_(actress)
# Joey Lauren Adams
# https://www.wikipedia.org/wiki/Joey_Lauren_Adams
# Julie Adams
# https://www.wikipedia.org/wiki/Gillian_Anderson
# Jacqueline Anderson
# https://www.wikipedia.org/wiki/Jacqueline_Anderson
# Loni Anderson
# https://www.wikipedia.org/wiki/Loni_Anderson
# Melissa Sue Anderson
# https://www.wikipedia.org/wiki/Melissa_Sue_Anderson
# Nicole Gale Anderson
# https://www.wikipedia.org/wiki/Nicole_Gale_Anderson
# Pamela Anderson
# https://www.wikipedia.org/wiki/Pamela_Anderson
# Robyn Adele Anderson
# https://www.wikipedia.org/wiki/Robyn_Adele_Anderson
# Paola Andino
# https://www.wikipedia.org/wiki/Paola_Andino
# Jaime Andrews
# https://www.wikipedia.org/wiki/Jaime_Andrews
# Meghan Andrews
# https://www.wikipedia.org/wiki/Meghan_Andrews
# Stephanie Andujar
# https://www.wikipedia.org/wiki/Stephanie_Andujar
# Auti Angel
# https://www.wikipedia.org/wiki/Auti_Angel
# Sharon Angela
# https://www.wikipedia.org/wiki/Sharon_Angela
# Felecia Angelle
# https://www.wikipedia.org/wiki/Felecia_Angelle
# Maya Angelou
# https://www.wikipedia.org/wiki/Maya_Angelou
# Genevieve Angelson
# https://www.wikipedia.org/wiki/Genevieve_Angelson
# Angelyne
# https://www.wikipedia.org/wiki/Angelyne
# Jennifer Aniston
# https://www.wikipedia.org/wiki/Jennifer_Aniston
# Ann-Margret
# https://www.wikipedia.org/wiki/Ann-Margret
# Odette Annable
# https://www.wikipedia.org/wiki/Odette_Annable
# Lulu Antariksa
# https://www.wikipedia.org/wiki/Lulu_Antariksa
# Shaindel Antelis
# https://www.wikipedia.org/wiki/Shaindel_Antelis
# Susan Anton
# https://www.wikipedia.org/wiki/Susan_Anton
# Devon Aoki
# https://www.wikipedia.org/wiki/Devon_Aoki
# Aparna Brielle
# https://www.wikipedia.org/wiki/Aparna_Brielle
# Iris Apatow
# https://www.wikipedia.org/wiki/Iris_Apatow
# Maude Apatow
# https://www.wikipedia.org/wiki/Maude_Apatow
# Johanna Parker Appel
# https://www.wikipedia.org/wiki/Johanna_Parker_Appel
# Shiri Appleby
# https://www.wikipedia.org/wiki/Shiri_Appleby
# Christina Applegate
# https://www.wikipedia.org/wiki/Christina_Applegate
# Bryn Apprill
# https://www.wikipedia.org/wiki/Bryn_Apprill
# Amy Aquino
# https://www.wikipedia.org/wiki/Amy_Aquino
# Lisa Arch
# https://www.wikipedia.org/wiki/Lisa_Arch
# Anne Archer
# https://www.wikipedia.org/wiki/Anne_Archer
# Emilia Ares
# https://www.wikipedia.org/wiki/Emilia_Ares
# Ashley Argota
# https://www.wikipedia.org/wiki/Ashley_Argota
# Nina Arianda
# https://www.wikipedia.org/wiki/Nina_Arianda
# Yareli Arizmendi
# https://www.wikipedia.org/wiki/Yareli_Arizmendi
# Adria Arjona
# https://www.wikipedia.org/wiki/Adria_Arjona
# Allisyn Ashley Arm
# https://www.wikipedia.org/wiki/Reiko_Aylesworth
# Rochelle Aytes
# https://www.wikipedia.org/wiki/Rochelle_Aytes
# Valerie Azlynn
# https://www.wikipedia.org/wiki/Valerie_Azlynn
# Barbara Babcock
# https://www.wikipedia.org/wiki/Barbara_Babcock
# Lauren Bacall
# https://www.wikipedia.org/wiki/Lauren_Bacall
# Morena Baccarin
# https://www.wikipedia.org/wiki/Morena_Baccarin
# Melissa Bacelar
# https://www.wikipedia.org/wiki/Melissa_Bacelar
# Catherine Bach
# https://www.wikipedia.org/wiki/Catherine_Bach
# Jillian Bach
# https://www.wikipedia.org/wiki/Jillian_Bach
# Sosie Bacon
# https://www.wikipedia.org/wiki/Sosie_Bacon
# Jane Badler
# https://www.wikipedia.org/wiki/Jane_Badler
# Lorri Bagley
# https://www.wikipedia.org/wiki/Lorri_Bagley
# Maxine Bahns
# https://www.wikipedia.org/wiki/Maxine_Bahns
# Iris Bahr
# https://www.wikipedia.org/wiki/Iris_Bahr
# Bai Ling
# https://www.wikipedia.org/wiki/Bai_Ling
# Katherine Bailess
# https://www.wikipedia.org/wiki/Katherine_Bailess
# Candace Bailey
# https://www.wikipedia.org/wiki/Candace_Bailey
# Cynthia Bailey
# https://www.wikipedia.org/wiki/Cynthia_Bailey
# Laura Bailey (voice actress)
# https://www.wikipedia.org/wiki/Laura_Bailey_(voice_actress)
# Adrienne Bailon
# https://www.wikipedia.org/wiki/Adrienne_Bailon
# Barbara Bain
# https://www.wikipedia.org/wiki/Barbara_Bain
# Robin Bain
# https://www.wikipedia.org/wiki/Robin_Bain
# Diora Baird
# https://www.wikipedia.org/wiki/Diora_Baird
# Baiyu (singer)
# https://www.wikipedia.org/wiki/Baiyu_(singer)
# Amanda Baker
# https://www.wikipedia.org/wiki/Amanda_Baker
# Andrea Baker
# https://www.wikipedia.org/wiki/Andrea_Baker
# Becky Ann Baker
# https://www.wikipedia.org/wiki/Becky_Ann_Baker
# Blanche Baker
# https://www.wikipedia.org/wiki/Blanche_Baker

# %% [markdown]
# #####  Step 3: Practice getting birthdate from one actress's wikipedia page
#
# Now that we know how to pull a list of actresses from one page in one category in Wikipedia, let's try to get the information that we want from their profile.

# %%
# Collect Meryl Streep's page
page_meryl = requests.get('https://en.wikipedia.org/wiki/Meryl_Streep')

# Collect a beautifulsoup object
soup_meryl = BeautifulSoup(page_meryl.text, 'html.parser')

# Get Meryl Streep's birthdate:
# Pull all content from the bday span
meryl_birthdate = soup_meryl.find(class_='bday')
birthday = meryl_birthdate.contents[0]
print(birthday)
# Out:
# 1949-06-22

# %%
# Get Meryl Streep's name:
# Pull all content from the firstHeading <h1> tag
meryl_name = soup_meryl.find(class_='firstHeading')
meryl = meryl_name.contents[0]
print(meryl)
# Out:
# Meryl Streep

# %%
allrows = soup_meryl.find_all(scope="row")
allrows
# Out:
# [<th scope="row">Born</th>,
#  <th scope="row">Alma mater</th>,
#  <th scope="row">Occupation</th>,
#  <th scope="row">Years active</th>,
#  <th scope="row"><span style="white-space:nowrap;">Works</span></th>,
#  <th scope="row"><span class="nowrap">Spouse(s)</span></th>,
#  <th scope="row"><span class="nowrap">Partner(s)</span></th>,
#  <th scope="row">Children</th>,
#  <th scope="row">Awards</th>,
#  <th scope="row">Website</th>,
#  <th class="navbox-group" scope="row" style="background: #EEDD82;width:1%">1928–1950</th>,
#  <th class="navbox-group" scope="row" style="background: #EEDD82;width:1%">1951–1975</th>,
#  <th class="navbox-group" scope="row" style="background: #EEDD82;width:1%">1976–2000</th>,
#  <th class="navbox-group" scope="row" style="background: #EEDD82;width:1%">2001–present</th>,
#  <th class="navbox-group" scope="row" style="background: #EEDD82;width:1%">1936–1950</th>,
#  <th class="navbox-group" scope="row" style="background: #EEDD82;width:1%">1951–1975</th>,
#  <th class="navbox-group" scope="row" style="background: #EEDD82;width:1%">1976–2000</th>,
#  <th class="navbox-group" scope="row" style="background: #EEDD82;width:1%">2001–present</th>,
#  <th class="navbox-group" scope="row" style="background: #BDB76B;width:1%;background: #C5B358">1952–1967</th>,
#  <th class="navbox-group" scope="row" style="background: #BDB76B;width:1%;background: #C5B358">1968–present</th>,
#  <th class="navbox-group" scope="row" style="width:1%;background: #BDB76B">Excellence in Film</th>,
#  <th class="navbox-group" scope="row" style="width:1%;background: #BDB76B">Excellence in Directing</th>,
#  <th class="navbox-group" scope="row" style="width:1%;background: #BDB76B">Worldwide Contribution to<br/>
#  Entertainment</th>,
#  <th class="navbox-group" scope="row" style="width:1%;background: #BDB76B">British Artist of the Year</th>,
#  <th class="navbox-group" scope="row" style="width:1%;background: #BDB76B">Excellence in Comedy</th>,
#  <th class="navbox-group" scope="row" style="width:1%;background: #BDB76B">Excellence in Television</th>,
#  <th class="navbox-group" scope="row" style="width:1%;background: #BDB76B">Humanitarian Award</th>,
#  <th class="navbox-group" scope="row" style="width:1%;background: #BDB76B">Retired Awards</th>,
#  <th class="navbox-group" scope="row" style="background: #40E0D0;width:1%">1980-1999</th>,
#  <th class="navbox-group" scope="row" style="background: #40E0D0;width:1%">2000-present</th>,
#  <th class="navbox-group" scope="row" style="width:1%">1946–1975</th>,
#  <th class="navbox-group" scope="row" style="width:1%">1976–2000</th>,
#  <th class="navbox-group" scope="row" style="width:1%">2001–present</th>,
#  <th class="navbox-group" scope="row" style="background: #DDBF5F;width:1%">1957–1975</th>,
#  <th class="navbox-group" scope="row" style="background: #DDBF5F;width:1%">1976–1996</th>,
#  <th class="navbox-group" scope="row" style="background: #CFB53B;width:1%">1943–1975</th>,
#  <th class="navbox-group" scope="row" style="background: #CFB53B;width:1%">1976–2000</th>,
#  <th class="navbox-group" scope="row" style="background: #CFB53B;width:1%">2001–present</th>,
#  <th class="navbox-group" scope="row" style="background: #CFB53B;width:1%">1940s</th>,
#  <th class="navbox-group" scope="row" style="background: #CFB53B;width:1%">1950s</th>,
#  <th class="navbox-group" scope="row" style="background: #CFB53B;width:1%">1960s</th>,
#  <th class="navbox-group" scope="row" style="background: #CFB53B;width:1%">1970s</th>,
#  <th class="navbox-group" scope="row" style="background: #CFB53B;width:1%">1980s</th>,
#  <th class="navbox-group" scope="row" style="background: #CFB53B;width:1%">1990s</th>,
#  <th class="navbox-group" scope="row" style="background: #CFB53B;width:1%">2000s</th>,
#  <th class="navbox-group" scope="row" style="background: #CFB53B;width:1%">2010s</th>,
#  <th class="navbox-group" scope="row" style="width:1%">1951–1975</th>,
#  <th class="navbox-group" scope="row" style="width:1%">1976–2000</th>,
#  <th class="navbox-group" scope="row" style="width:1%">2001–present</th>,
#  <th class="navbox-group" scope="row" style="width:1%">1976–2000</th>,
#  <th class="navbox-group" scope="row" style="width:1%">2001–present</th>,
#  <th class="navbox-group" scope="row" style="width:1%">2010</th>,
#  <th class="navbox-group" scope="row" style="width:1%">2011</th>,
#  <th class="navbox-group" scope="row" style="width:1%">2012</th>,
#  <th class="navbox-group" scope="row" style="width:1%">2013</th>,
#  <th class="navbox-group" scope="row" style="width:1%">2014</th>,
#  <th class="navbox-group" scope="row" style="width:1%">2015</th>,
#  <th class="navbox-group" scope="row" style="width:1%">2016</th>,
#  <th class="navbox-group" scope="row" style="width:1%">2017</th>,
#  <th class="navbox-group" scope="row" style="width:1%">1966-1979</th>,
#  <th class="navbox-group" scope="row" style="width:1%">1980-1999</th>,
#  <th class="navbox-group" scope="row" style="width:1%">2000-present</th>,
#  <th class="navbox-group" scope="row" style="width:1%">1967–1979</th>,
#  <th class="navbox-group" scope="row" style="width:1%">1980–1999</th>,
#  <th class="navbox-group" scope="row" style="width:1%">2000–present</th>,
#  <th class="navbox-group" scope="row" style="width:1%">1935–1940</th>,
#  <th class="navbox-group" scope="row" style="width:1%">1941–1960</th>,
#  <th class="navbox-group" scope="row" style="width:1%">1961–1980</th>,
#  <th class="navbox-group" scope="row" style="width:1%">1981–2000</th>,
#  <th class="navbox-group" scope="row" style="width:1%">2001–present</th>,
#  <th class="navbox-group" scope="row" style="width:1%">1969–1980</th>,
#  <th class="navbox-group" scope="row" style="width:1%">1981–2000</th>,
#  <th class="navbox-group" scope="row" style="width:1%">2001–present</th>,
#  <th class="navbox-group" scope="row" style="width:1%">Musical or Comedy<br/>
#  (1996–2010, retired)</th>,
#  <th class="navbox-group" scope="row" style="width:1%">Motion Picture Drama<br/>
#  (1996–2010, retired)</th>,
#  <th class="navbox-group" scope="row" style="width:1%">Motion Picture<br/>
#  (2011–present)</th>,
#  <th class="navbox-group" scope="row" style="width:1%">2004</th>,
#  <th class="navbox-group" scope="row" style="width:1%">2005</th>,
#  <th class="navbox-group" scope="row" style="width:1%">2006</th>,
#  <th class="navbox-group" scope="row" style="width:1%">2007</th>,
#  <th class="navbox-group" scope="row" style="width:1%">2009</th>,
#  <th class="navbox-group" scope="row" style="width:1%">2011</th>,
#  <th class="navbox-group" scope="row" style="width:1%">2012</th>,
#  <th class="navbox-group" scope="row" style="width:1%">2013</th>,
#  <th class="navbox-group" scope="row" style="width:1%">2014</th>,
#  <th class="navbox-group" scope="row" style="width:1%">2015</th>,
#  <th class="navbox-group" scope="row" style="width:1%">2016</th>,
#  <th class="navbox-group" scope="row" style="width:1%">2017</th>,
#  <th class="navbox-group" scope="row" style="background: #ABCDEF;width:1%">1990s</th>,
#  <th class="navbox-group" scope="row" style="background: #ABCDEF;width:1%">2000s</th>,
#  <th class="navbox-group" scope="row" style="background: #ABCDEF;width:1%">2010s</th>,
#  <th class="navbox-group" scope="row" style="width:1%"><a href="/wiki/Help:Authority_control" title="Help:Authority control">Authority control</a></th>]

# %%
# Create a file to write to, add headers row
f_meryl = csv.writer(open('actress-birthdates.csv', 'w'))
f_meryl.writerow(['Name', 'Birthdate'])

# Add row with Meryl's information
f_meryl.writerow([meryl, birthday])
# Out:
# 25
